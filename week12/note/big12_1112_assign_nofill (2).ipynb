# %% [markdown]
#
# 과제1) 인천광역시 미추홀구_재래시장_20220822.csv 화일에 포함되어 있는
# 재래시장들의 위치를 marker에 표시 하시오.
#  지도의 중심 위치는 7호관뒤 수준 원점으로 설정 하시오
#  marker를 클릭 했을때 시장 이름이 나타나도록 설정

# %%
# -*- coding: utf-8 -*-

# 라이브러리 불러오기
import pandas as pd
import folium

#  데이터프레임 변환
df = pd.read_csv('/content/인천광역시 미추홀구_재래시장_20220822.csv',  encoding = 'CP949')  # 수준원점 기준 

print(df)
# 지도 만들기

# %% [markdown]
# 과제2) 서울특별시 성북구_약국list.csv 화일에 포함되어 있는
# 약국들의 위치를 circlemarker로 표시 하시오.
#  지도의 중심 위치는 성북 구청으로 설정 하시오
#  circlemarker를 클릭 했을때 약국 이름이 나타나도록 설정

# %%
# -*- coding: utf-8 -*-

# 라이브러리 불러오기
import pandas as pd
import folium

#  리스트를 데이터프레임 변환
df = pd.read_csv('/content/서울특별시 성북구_약국list.csv',  encoding = 'CP949')

# %% [markdown]
# 과제3. 서울시의 구별 인구수 ( 총생활인구수    )를 단계 구분도(choropleth)를 이용하여 표시 하시오.
# 구분이 잘 되도록 threshold_scale을 적절히 설정.
#
# chprpleth 함수의 parameter 중 key_on은
# 'feature.properties.name' 으로 설정.

# %%
import pandas as pd

import folium

df=pd.read_csv('/content/서울구별인구.csv')
#df.columns = df.columns.map(str)


print(df.head())
import requests
import json
import re

# 서울 행정구역 json raw파일(githubcontent)https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json
s_geo='https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'

s_map = folium.Map(location=[37.559984,126.9753071],  # 숭례문 위도, 경도
                   tiles='Stamen Terrain', zoom_start=11)


s_map
# Out:
#       기준일ID  시군구코드 시군구명  인구수       총생활인구수     내국인생활인구수  장기체류외국인인구수  \
# 0  20221105  11110  종로구  299  299711.6286  269531.1395  17687.8690
# 1  20221105  11140   중구  268  268413.4217  215788.9233  17730.5069
# 2  20221105  11170  용산구  296  296264.2489  272201.6028  16908.7793
# 3  20221105  11200  성동구  346  346978.2575  327533.3117  16690.4480
# 4  20221105  11215  광진구  385  385909.7098  360337.6724  22446.5917
#
#    단기체류외국인인구수       일최대인구수       일최소인구수  주간인구수(09~18)  야간인구수(19~08)  \
# 0  12492.6201  420491.3983  229367.8299   368107.3021   250857.5762
# 1  34893.9915  344814.2942  209744.7507   321168.3035   230731.3633
# 2   7153.8669  326482.8175  274015.5366   313517.5125   283940.4892
# 3   2754.4978  365868.2481  332101.4179   354076.2544   341908.2597
# 4   3125.4457  395090.8185  376791.2038   379787.5538   390282.6784
#
#       일최대이동인구수    서울외유입인구수  동일자치구행정동간이동인구수    자치구간이동인구수
# 0  253376.9511  88685.1264      28580.2546  136111.5701
# 1  204500.4984  63200.6201      26755.0629  114544.8154
# 2  166080.4940  51253.1096      41897.0890   72930.2954
# 3  179253.0773  41237.6455      54451.9150   83563.5168
# 4  168555.0409  38592.6934      70825.0044   59137.3431
# 0      종로구
# 1       중구
# 2      용산구
# 3      성동구
# 4      광진구
# 5     동대문구
# 6      중랑구
# 7      성북구
# 8      강북구
# 9      도봉구
# 10     노원구
# 11     은평구
# 12    서대문구
# 13     마포구
# 14     양천구
# 15     강서구
# 16     구로구
# 17     금천구
# 18    영등포구
# 19     동작구
# 20     관악구
# 21     서초구
# 22     강남구
# 23     송파구
# 24     강동구
# Name: 시군구명, dtype: object
#       기준일ID  시군구코드 시군구명  인구수       총생활인구수     내국인생활인구수  장기체류외국인인구수  \
# 50%    16113.841500   3125.445700  420491.398300  376791.203800
# 75%    20311.033500   7153.866900  528660.425500  451602.758500
# max    39860.045800  34893.991500  886469.260500  725850.164000
#
#         주간인구수(09~18)   야간인구수(19~08)       일최대이동인구수       서울외유입인구수  \
# count      25.000000      25.000000      25.000000      25.000000
# mean   424874.384824  421120.301228  202436.863336   51949.422808
# std    143477.513654  132003.718261   78670.478758   32576.237053
# min    210765.216700  217821.548300   98584.614400   14282.466700
# 25%    354076.254400  341908.259700  158158.316100   30676.903800
# 50%    379787.553800  409505.535400  178736.241200   38592.693400
# 75%    479052.291100  497935.744900  220034.790500   63200.620100
# max    850779.600500  740632.501000  457278.407400  147525.634600
#
#        동일자치구행정동간이동인구수      자치구간이동인구수
# count       25.000000      25.000000
# mean     77507.989196   72979.451332
# std      29909.562242   40437.726707
# min      26755.062900   28162.063400
# 25%      61284.741900   47623.254900
# 50%      72780.729500   58951.495400
# 75%      91391.542600   94676.934800
# max     142468.078300  196356.192500
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   기준일ID           25 non-null     int64
#  1   시군구코드           25 non-null     int64
#  2   시군구명            25 non-null     object
#  3   인구수             25 non-null     int64
#  4   총생활인구수          25 non-null     float64
#  5   내국인생활인구수        25 non-null     float64
#  6   장기체류외국인인구수      25 non-null     float64
#  7   단기체류외국인인구수      25 non-null     float64
#  8   일최대인구수          25 non-null     float64
#  9   일최소인구수          25 non-null     float64
#  10  주간인구수(09~18)    25 non-null     float64
#  11  야간인구수(19~08)    25 non-null     float64
#  12  일최대이동인구수        25 non-null     float64
#  13  서울외유입인구수        25 non-null     float64
#  14  동일자치구행정동간이동인구수  25 non-null     float64
#  15  자치구간이동인구수       25 non-null     float64
# dtypes: float64(12), int64(3), object(1)
# memory usage: 3.2+ KB
# None
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a30e10caaa0ba99712c62093339b9cca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a30e10caaa0ba99712c62093339b9cca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a30e10caaa0ba99712c62093339b9cca = L.map(
#                 &quot;map_a30e10caaa0ba99712c62093339b9cca&quot;,
#                 {
#                     center: [37.559984, 126.9753071],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0328bf7b0b1331381f89aa324d8c68a = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a30e10caaa0ba99712c62093339b9cca);
#
#
#             var choropleth_edd238f8b9bc6cc1eff5cbfbdf87cfef = L.featureGroup(
#                 {}
#             ).addTo(map_a30e10caaa0ba99712c62093339b9cca);
#
#
#         function geo_json_625321d9f17e9d434eb4572428b181f7_styler(feature) {
#             switch(feature.properties.code) {
#                 case &quot;11250&quot;: case &quot;11220&quot;: case &quot;11160&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;11240&quot;: case &quot;11230&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;11210&quot;: case &quot;11190&quot;: case &quot;11170&quot;: case &quot;11140&quot;: case &quot;11120&quot;: case &quot;11110&quot;: case &quot;11080&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;11180&quot;: case &quot;11100&quot;: case &quot;11090&quot;: case &quot;11030&quot;: case &quot;11020&quot;: case &quot;11010&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_625321d9f17e9d434eb4572428b181f7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_625321d9f17e9d434eb4572428b181f7 = L.geoJson(null, {
#                 onEachFeature: geo_json_625321d9f17e9d434eb4572428b181f7_onEachFeature,
#
#                 style: geo_json_625321d9f17e9d434eb4572428b181f7_styler,
#         });
#
#         function geo_json_625321d9f17e9d434eb4572428b181f7_add (data) {
#             geo_json_625321d9f17e9d434eb4572428b181f7
#                 .addData(data)
#                 .addTo(choropleth_edd238f8b9bc6cc1eff5cbfbdf87cfef);
#         }
#             geo_json_625321d9f17e9d434eb4572428b181f7_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.5191871
